# %%
import pandas
import numpy as np
from keras import *
from matplotlib import pyplot
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow import math
from plot_keras_history import plot_history

import pywt

# %%
data_frame = pandas.read_csv("bonn_dataset.csv")

labels = data_frame['y']
first_column = data_frame.columns[0]
data = data_frame.copy()
data.pop(first_column)
data.pop('y')
# Out:
# 0        4
# 1        1
# 2        5
# 3        5
# 4        5
#         ..
# 11495    2
# 11496    1
# 11497    5
# 11498    3
# 11499    4
# Name: y, Length: 11500, dtype: int64

# %%
# print(data.shape[1])

def cnn_model():
    model = Sequential(name='cnn')

    inputs = Input(shape=(data.shape[1], 1))

    model.add(inputs)
    model.add(layers.Reshape((data.shape[1], 1)))
    # model.add(layers.Conv1D(64, 25, activation='relu'))
    model.add(layers.Conv1D(32, 15, activation='relu'))
    model.add(layers.Conv1D(16, 10, activation='relu'))
    model.add(layers.Conv1D(8, 5, activation='relu'))
    model.add(layers.MaxPooling1D())
    model.add(layers.Flatten())
    # model.add(layers.Dense(100, activation='sigmoid'))
    model.add(layers.Dense(40, activation='sigmoid'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(5, activation='softmax'))
    
    return model
cnn_model().summary()
# Out:
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 178, 1)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 164, 32)           512
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 155, 16)           5136
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 151, 8)            648
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 75, 8)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 600)               0
# _________________________________________________________________
# dense (Dense)                (None, 40)                24040
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 205
# =================================================================
# Total params: 30,541
# Trainable params: 30,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test the model using 10 fold cross validation
# random_state is use, so the same result will be obtained
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1337)

accuracy_fold = []
loss_fold = []

# %%
fold_nr = 0

for train_indexes, test_indexes in kf.split(data, labels):
    x_train = data.iloc[train_indexes]
    y_train_multilabel = labels.iloc[train_indexes]
    y_train = pandas.get_dummies(y_train_multilabel, prefix='state')
    
    
    x_test = data.iloc[test_indexes]
    y_test_multilabel = labels.iloc[test_indexes]
    y_test = pandas.get_dummies(y_test_multilabel, prefix='state')
    
    # define a new model
    model = cnn_model()
    model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    
    print("----------------------------------------------------------------------")
    print("Training for fold nr: {}".format(fold_nr))
    history = model.fit(x_train, y_train, batch_size=32, epochs=50, verbose=0)
    
    loss, accuracy = model.evaluate(x_test, y_test)
    
    print("Test Loss: {}".format(loss))
    print("Test Accuracy: {}".format(accuracy))
    
    accuracy_fold.append(accuracy)
    loss_fold.append(loss)
    
    fold_nr += 1
    print("----------------------------------------------------------------------")
# Out:
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 0
# 36/36 [==============================] - 0s 3ms/step - loss: 0.4950 - accuracy: 0.7652
# Test Loss: 0.4949807822704315
# Test Accuracy: 0.7652173638343811
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 1
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7311 - accuracy: 0.6522
# Test Loss: 0.7310667037963867
# Test Accuracy: 0.6521739363670349
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 2
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5428 - accuracy: 0.7548
# Test Loss: 0.5428229570388794
# Test Accuracy: 0.7547826170921326
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 3
# 36/36 [==============================] - 0s 2ms/step - loss: 0.5170 - accuracy: 0.7652
# Test Loss: 0.5169811844825745
# Test Accuracy: 0.7652173638343811
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 4
# 36/36 [==============================] - 0s 2ms/step - loss: 0.5091 - accuracy: 0.7652
# Test Loss: 0.5090985298156738
# Test Accuracy: 0.7652173638343811
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 5
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.7774
# Test Loss: 0.5143669247627258
# Test Accuracy: 0.7773913145065308
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 6
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6067 - accuracy: 0.7043
# Test Loss: 0.6066811680793762
# Test Accuracy: 0.7043478488922119
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 7
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5629 - accuracy: 0.7478
# Test Loss: 0.5628597140312195
# Test Accuracy: 0.747826099395752
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 8
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5569 - accuracy: 0.7374
# Test Loss: 0.5568728446960449
# Test Accuracy: 0.7373912930488586
# History plots:
# ----------------------------------------------------------------------
# 10350
# 10350
# ----------------------------------------------------------------------
# Training for fold nr: 9
# 36/36 [==============================] - 0s 3ms/step - loss: 0.5798 - accuracy: 0.7391
# Test Loss: 0.5797635316848755
# Test Accuracy: 0.739130437374115
# History plots:
# ----------------------------------------------------------------------

# %%
print("Average Loss for the model: {}".format(sum(loss_fold) / 10))
print("Average accuracy for the model: {}".format(sum(accuracy_fold) / 10))
# Out:
# Average Loss for the model: 0.5615494340658188
# Average accuracy for the model: 0.7408695638179779

# %%
# row.plot()
# pyplot.show()

filtered_data = []
wavelets = ['db6', 'sym6', 'coif2'] # all these wavelets produce coefficients of the same length

# row = data.iloc[0]
# ca, cd = pywt.dwt(row, 'coif2')
# print(len(cd))

for i in range(len(data)):
    row = data.iloc[i]
    
    new_row = []
    
    for wt in wavelets:
        ca, cd = pywt.dwt(row, wt)
        new_row.append(ca)
        new_row.append(cd)
    
    filtered_data.append(np.array(new_row))

filtered_data = np.array(filtered_data)

# %%
# print(filtered_data)
def filtered_cnn(shape):
    model = Sequential(name='filtered')
    model.add(Input(shape=shape[1:]))
    model.add(layers.Reshape((shape[2], shape[1])))
    model.add(layers.Conv1D(32, 15, activation='relu'))
    model.add(layers.Conv1D(16, 10, activation='relu'))
    model.add(layers.Conv1D(8, 5, activation='relu'))
    model.add(layers.MaxPooling1D())
    model.add(layers.Flatten())
    # model.add(layers.Dense(100, activation='sigmoid'))
    model.add(layers.Dense(50, activation='sigmoid'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(5, activation='softmax'))
    
    return model
          
filtered_cnn(filtered_data.shape).summary()
# Out:
# Model: "filtered"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_13 (Reshape)         (None, 94, 6)             0
# _________________________________________________________________
# conv1d_46 (Conv1D)           (None, 80, 32)            2912
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 71, 16)            5136
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 67, 8)             648
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 33, 8)             0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 264)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 50)                13250
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 5)                 255
# =================================================================
# Total params: 22,201
# Trainable params: 22,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1337)

accuracy_fold = []
loss_fold = []

fold_nr = 0

for train_indexes, test_indexes in kf.split(data, labels):
    x_train = data.iloc[train_indexes]
    y_train_multilabel = labels.iloc[train_indexes]
    y_train = pandas.get_dummies(y_train_multilabel, prefix='state')
    
    
    x_test = data.iloc[test_indexes]
    y_test_multilabel = labels.iloc[test_indexes]
    y_test = pandas.get_dummies(y_test_multilabel, prefix='state')
    
    # define a new model
    model = filtered_cnn_model()
    model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    
    print("----------------------------------------------------------------------")
    print("Training for fold nr: {}".format(fold_nr))
    history = model.fit(x_train, y_train, batch_size=32, epochs=50, verbose=0)
    
    loss, accuracy = model.evaluate(x_test, y_test)
    
    print("Test Loss: {}".format(loss))
    print("Test Accuracy: {}".format(accuracy))
    
    accuracy_fold.append(accuracy)
    loss_fold.append(loss)
    
    fold_nr += 1
    print("----------------------------------------------------------------------")

# y = pandas.get_dummies(labels, prefix='state')
# # print(y)
# x_train, x_test, y_train, y_test = train_test_split(filtered_data, y, test_size=0.1, random_state=1337)
# model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
# history = model.fit(x_train, y_train, batch_size=32, epochs=40)
# loss, accuracy = model.evaluate(x_test, y_test)
